# %%
#string methodlari
#regular ifadeler
#gercek veri setinde uygulama

"selam".upper()
# Out:
# 'SELAM'

# %%
import pandas as pd ; import numpy as np

# %%
#gomulu string methodlari 
veri = ["Ali","BERk","DeNiz",np.nan,"zEYNEP"]
veri
# Out:
# ['Ali', 'BERk', 'DeNiz', nan, 'zEYNEP']

# %%
isim = pd.Series(veri)

# %%
#once veri ismi , sorna str, en son da ne yaomak istedigimiz 
#ilk harflari buyuk yaptik
isim.str.capitalize()
# Out:
# 0       Ali
# 1      Berk
# 2     Deniz
# 3       NaN
# 4    Zeynep
# dtype: object

# %%
#randon df olusturuyoruz 
df= pd.DataFrame(np.random.randn(3,2),
                 columns = ["sutun A","Sutun B"],
                 index = range(3))
df
# Out:
#     sutun A   Sutun B
# 0  2.422766 -1.610372
# 1 -2.052479 -0.876076
# 2  2.152933 -0.530398

# %%
df.columns
# Out:
# Index(['sutun A', 'Sutun B'], dtype='object')

# %%
#sutun isimlerini de kucuk buyu kharf gibi seylerle degistirebiliriz 
df.columns.str.lower().str.replace(" ","_")
# Out:
# Index(['sutun_a', 'sutun_b'], dtype='object')

# %%
#liste dondurme 
s= pd.Series(["a_b_c","c_d_e", np.nan,"f_g_h"])
s
# Out:
# 0    a_b_c
# 1    c_d_e
# 2      NaN
# 3    f_g_h
# dtype: object

# %%
#split methodu ile yaziyi ayirma 
#ayrica her degerin 1. birimini yazdirma 
s.str.split("_").str.get(1)
# Out:
# 0      b
# 1      d
# 2    NaN
# 3      g
# dtype: object

# %%
#expand ile fataframe e cevirebiliriz 
s.str.split("_",expand = True, n=1)
# Out:
#      0    1
# 0    a  b_c
# 1    c  d_e
# 2  NaN  NaN
# 3    f  g_h

# %%
#text duzenleme
para = pd.Series(["15","-$20","$30000"])
para
# Out:
# 0        15
# 1      -$20
# 2    $30000
# dtype: object

# %%
#dolar isaretini kaldiralim 
para.str.replace("$","")
# Out:
# 0       15
# 1      -20
# 2    30000
# dtype: object

# %%
#hem dolar hem de eksiyi silmek icin , ters / kllanilir 
#bu calismadi 
#para.str.replace("-\$","")

# %%
para.str.isalnum()
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %%
#gercek veri ile uygulama yapalim
film = pd.read_csv("DataSets/netflix_titles.csv")
film
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#ilk 5 satiri yazdirdik 
film.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#her harfi buyuk yaptik 
film.title.str.upper()
# Out:
# 0        DICK JOHNSON IS DEAD
# 1               BLOOD & WATER
# 2                   GANGLANDS
# 3       JAILBIRDS NEW ORLEANS
# 4                KOTA FACTORY
#                 ...
# 8802                   ZODIAC
# 8803              ZOMBIE DUMB
# 8804               ZOMBIELAND
# 8805                     ZOOM
# 8806                   ZUBAAN
# Name: title, Length: 8807, dtype: object

# %%
#buyuk sutunlari gormek icin 
film.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#butun sutunlar buyuk harfle baslasin 
film.columns = film.columns.str.capitalize()

# %%
#listede gorebiliyoruz 
film.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            Date_added  Release_year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#actor listesinde Brad Pitt var mi ? 
#once NaN degerleri None ile degistirdik 
film.fillna("None", inplace=True)

# %%
film[film.Cast.str.contains("Brad Pitt")]
# Out:
#      Show_id   Type                       Title               Director  \
# 630     s631  Movie         Killing Them Softly         Andrew Dominik
# 2903   s2904  Movie                  By the Sea         Angelina Jolie
# 5473   s5474  Movie                 War Machine           David Michôd
# 5942   s5943  Movie  A Stoning in Fulham County          Larry Elikann
# 6205   s6206  Movie                       Babel  Alejandro G. Iñárritu
# 7077   s7078  Movie        Inglourious Basterds      Quentin Tarantino
# 7638   s7639  Movie            Ocean's Thirteen      Steven Soderbergh
# 7639   s7640  Movie              Ocean's Twelve      Steven Soderbergh
#
#                                                    Cast  \
# 630   Brad Pitt, Scoot McNairy, Ben Mendelsohn, Rich...
# 2903  Angelina Jolie, Brad Pitt, Mélanie Laurent, Me...
# 5473  Brad Pitt, Topher Grace, Emory Cohen, John Mag...
# 5942  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...
# ...

# %%
#aradaki karakterleri kaldirma/degistirme 
film.Cast.str.replace(",","-")
# Out:
# 0                                                    None
# 1       Ama Qamata- Khosi Ngema- Gail Mabalane- Thaban...
# 2       Sami Bouajila- Tracy Gotoas- Samuel Jouy- Nabi...
# 3                                                    None
# 4       Mayur More- Jitendra Kumar- Ranjan Raj- Alam K...
#                               ...
# 8802    Mark Ruffalo- Jake Gyllenhaal- Robert Downey J...
# 8803                                                 None
# 8804    Jesse Eisenberg- Woody Harrelson- Emma Stone- ...
# 8805    Tim Allen- Courteney Cox- Chevy Chase- Kate Ma...
# 8806    Vicky Kaushal- Sarah-Jane Dias- Raaghav Chanan...
# Name: Cast, Length: 8807, dtype: object

# %%
film.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water             None
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans             None
# 4      s5  TV Show           Kota Factory             None
#
#                                                 Cast        Country  \
# 0                                               None  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           None
# 3                                               None           None
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            Date_added  Release_year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...
