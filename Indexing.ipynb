# %%
import pandas as pd

# %%
df = pd.read_csv('DataSets/vgsales.csv', index_col= 'Genre')
df
# Out:
#              Rank                                               Name Platform  \
# Genre
# Shooter       259                                          Asteroids     2600
# Shooter       545                                    Missile Command     2600
# Misc         1768                                            Kaboom!     2600
# Misc         1971                                           Defender     2600
# Fighting     2671                                             Boxing     2600
# ...           ...                                                ...      ...
# Platform    16565                                       Mighty No. 9     XOne
# Shooter     16572                                 Resident Evil 4 HD     XOne
# Simulation  16573                      Farming 2017 - The Simulation      PS4
# Sports      16579                                  Rugby Challenge 3     XOne
# Action      16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16324 entries, 0 to 16323
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16324 non-null  int64
#  1   Name          16324 non-null  object
#  2   Platform      16324 non-null  object
#  3   Year          16324 non-null  int64
#  4   Genre         16324 non-null  object
#  5   Publisher     16288 non-null  object
#  6   NA_Sales      16324 non-null  float64
#  7   EU_Sales      16324 non-null  float64
#  8   JP_Sales      16324 non-null  float64
#  9   Other_Sales   16324 non-null  float64
#  10  Global_Sales  16324 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.4+ MB

# %%
#oublisheri sildik 
df.drop(labels=['Publisher'], axis = 1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16324 entries, Shooter to Action
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16324 non-null  int64
#  1   Name          16324 non-null  object
#  2   Platform      16324 non-null  object
#  3   Year          16324 non-null  int64
#  4   NA_Sales      16324 non-null  float64
#  5   EU_Sales      16324 non-null  float64
#  6   JP_Sales      16324 non-null  float64
#  7   Other_Sales   16324 non-null  float64
#  8   Global_Sales  16324 non-null  float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 1.2+ MB

# %%
#eri almak icin
#we can also do df.set_index('Genre') to add index 
df.reset_index()
# Out:
#             Genre   Rank                                               Name  \
# 0         Shooter    259                                          Asteroids
# 1         Shooter    545                                    Missile Command
# 2            Misc   1768                                            Kaboom!
# 3            Misc   1971                                           Defender
# 4        Fighting   2671                                             Boxing
# ...           ...    ...                                                ...
# 16319    Platform  16565                                       Mighty No. 9
# 16320     Shooter  16572                                 Resident Evil 4 HD
# 16321  Simulation  16573                      Farming 2017 - The Simulation
# 16322      Sports  16579                                  Rugby Challenge 3
# 16323      Action  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...
#
# ...

# %%
df
# Out:
#              Rank                                               Name Platform  \
# Genre
# Shooter       259                                          Asteroids     2600
# Shooter       545                                    Missile Command     2600
# Misc         1768                                            Kaboom!     2600
# Misc         1971                                           Defender     2600
# Fighting     2671                                             Boxing     2600
# ...           ...                                                ...      ...
# Platform    16565                                       Mighty No. 9     XOne
# Shooter     16572                                 Resident Evil 4 HD     XOne
# Simulation  16573                      Farming 2017 - The Simulation      PS4
# Sports      16579                                  Rugby Challenge 3     XOne
# Action      16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
# ...
